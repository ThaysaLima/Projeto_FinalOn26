# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_candidatos = pd.read_csv('candidatos.csv', encoding='latin1', sep=';', na_values=['#NULO', '#NE'])
df_candidatos
# Out:
#         Ano de eleição          Cargo  \
# 0                 2016       Prefeito
# 1                 2016       Prefeito
# 2                 2016       Prefeito
# 3                 2016       Prefeito
# 4                 2016       Prefeito
# ...                ...            ...
# 496027            2016  Vice-prefeito
# 496028            2016  Vice-prefeito
# 496029            2016  Vice-prefeito
# 496030            2016  Vice-prefeito
# 496031            2016  Vice-prefeito
#
#                                                 Coligação Cor/raça  \
# 0                                 A MUDANÇA QUE VOCÊ QUER   Branca
# 1               CASTELO CIDADE SORRISO, VOLTANDO A SORRIR   Branca
# 2                           PT / PTN / PR / PRB / PSD/PDT   Branca
# 3                            " ATIBAIA SEMPRE EM FRENTE "   Branca
# 4                             " COM FÉ E A FORÇA DO POVO"    Parda
# ...                                                   ...      ...
# ...

# %%
df_candidatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496032 entries, 0 to 496031
# Data columns (total 29 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Ano de eleição                            496032 non-null  int64
#  1   Cargo                                     496032 non-null  object
#  2   Coligação                                 496032 non-null  object
#  3   Cor/raça                                  496032 non-null  object
#  4   Detalhe da situação de candidatura        496032 non-null  object
#  5   Estado civil                              496032 non-null  object
#  6   Faixa etária                              496032 non-null  object
#  7   Federação                                 496032 non-null  object
#  8   Gênero                                    496032 non-null  object
#  9   Grau de instrução                         496032 non-null  object
# ...

# %%
coluna = ['Situação de totalização', 'Tipo eleição','Detalhe da situação de candidatura', 'Município']
coluna2 = ['Ocupação','Nacionalidade','Região','Tipo eleição']
coluna3 = ['Turno']
desejadas = df_candidatos.loc[:, coluna]
desejadas
# Out:
#        Situação de totalização         Tipo eleição  \
# 0                   Não eleito    Eleição Ordinária
# 1                   Não eleito  Eleição Suplementar
# 2                   Não eleito    Eleição Ordinária
# 3                       Eleito    Eleição Ordinária
# 4                   Não eleito    Eleição Ordinária
# ...                        ...                  ...
# 496027              Não eleito    Eleição Ordinária
# 496028              Não eleito    Eleição Ordinária
# 496029              Não eleito    Eleição Ordinária
# 496030                  Eleito    Eleição Ordinária
# 496031              Não eleito    Eleição Ordinária
#
#        Detalhe da situação de candidatura              Município
# 0                                Deferido             SÃO CARLOS
# 1                              Indeferido                CASTELO
# 2                                Deferido              NHANDEARA
# 3                                Deferido                ATIBAIA
# ...
